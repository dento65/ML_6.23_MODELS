# %%
import torch
import numpy as np
import pandas as pd
from torch.utils.data import DataLoader
from torch.utils.data import TensorDataset
import torch.nn.functional as F
import torch.nn as nn

# %%
d = pd.read_csv('/Users/hayat/Downloads/wea.csv')

# %%
df=pd.DataFrame(d)
nd = pd.DataFrame(columns=['Year0', 'Month0', 'Temperature0', 'Rain0','Year1', 'Month1', 'Temperature1', 'Rain1'])
print(df.columns)
# nd.loc[len(nd.index)] = ['Amy', 89, 93]
print(len(df))
count=0

print(df.loc[0,:])
# for x in range(0,20):
#     nd.loc[count,:]=[df['Year'][x],df['Month'][x],df['Temperature '][x],df['Rain'][x],0,0,0,0]
#     count+=1 
for x in range(0,20):
#     df.loc[0,:]=[3,4,3,2]
#     print(df.loc[0,:])
    for y in range(0,20):
        nd.loc[count,:]=[df['Year'][x],df['Month'][x],df['Temperature '][x],df['Rain'][x],df['Year'][y],df['Month'][y],df['Temperature '][y],df['Rain'][y]]
        count+=1
# Out:
# Index(['Year', 'Month', 'Temperature ', 'Rain'], dtype='object')
# 1428
# Year            1901.00
# Month              1.00
# Temperature       16.98
# Rain              18.54
# Name: 0, dtype: float64

# %%
print(len(nd))
# result = df["Rain"]
# test = df.drop(["Rain"],axis=1)
# result = result[:50]
# test = test[:50]
result = nd["Rain0"]
test = nd.drop(["Rain0","Rain1"],axis=1)
# Out:
# 400

# %%
from torch.utils.data import random_split
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(test, result, test_size=0.3, random_state=1)
X_train,y_train
# Out:
# (    Year0 Month0 Temperature0 Year1 Month1 Temperature1
#  39   1901      2         19.9  1902      8         28.1
#  167  1901      9        27.61  1901      8        27.92
#  383  1902      8         28.1  1901      4        28.18
#  221  1901     12        18.56  1901      2         19.9
#  351  1902      6        28.27  1901     12        18.56
#  ..    ...    ...          ...   ...    ...          ...
#  255  1902      1        18.55  1902      4        26.56
#  72   1901      4        28.18  1902      1        18.55
#  396  1902      8         28.1  1902      5        27.32
#  235  1901     12        18.56  1902      4        26.56
#  37   1901      2         19.9  1902      6        28.27
#
#  [280 rows x 6 columns],
#  39      16.25
#  167    291.55
#  383    435.17
#  221      1.69
#  351    528.78
#          ...
#  255      1.29
#  72      66.16
#  396    435.17
#  235      1.69
#  37      16.25
#  Name: Rain0, Length: 280, dtype: object)

# %%
#Import svm model
from sklearn import svm
from sklearn.tree import DecisionTreeRegressor
#Create a svm Classifier
clf = DecisionTreeRegressor(max_depth=2) # Linear Kernel

#Train the model using the training sets
clf.fit(X_train, y_train)

#Predict the response for test dataset
y_pred = clf.predict(X_test)

# %%
from sklearn import metrics

# Model Accuracy: how often is the classifier correct?
accuracy = clf.score(X_test, y_test)
print(accuracy)
# Out:
# 0.8174318883578263

# %%
result = clf.predict(X_test)

# %%
print(result,y_test)
# Out:
# [188.97363658 188.97363658 428.98479736 188.97363658  26.12714287
#  428.98479736 428.98479736  26.12714287  26.12714287  26.12714287
#   26.12714287 234.19666513  26.12714287  26.12714287  26.12714287
#  428.98479736  26.12714287  26.12714287 234.19666513 428.98479736
#  234.19666513  26.12714287  26.12714287  26.12714287 188.97363658
#  428.98479736  26.12714287 428.98479736 428.98479736 234.19666513
#  428.98479736 428.98479736  26.12714287  26.12714287  26.12714287
#  234.19666513  26.12714287 428.98479736 428.98479736  26.12714287
#  428.98479736  26.12714287  26.12714287 234.19666513  26.12714287
#  428.98479736  26.12714287 428.98479736 234.19666513 234.19666513
#   26.12714287 428.98479736 428.98479736 428.98479736  26.12714287
#   26.12714287  26.12714287  26.12714287  26.12714287  26.12714287
#   26.12714287 428.98479736 428.98479736 428.98479736 234.19666513
#  428.98479736 234.19666513  26.12714287  26.12714287 234.19666513
# ...

# %%
count=0
tr = pd.DataFrame(columns=['Year0', 'Month0', 'Temperature0', 'Rain0','Year1', 'Month1', 'Temperature1', 'Rain1'])

for x in range(220,230):
#     df.loc[0,:]=[3,4,3,2]
#     print(df.loc[0,:])
    for y in range(220,230):
        nd.loc[count,:]=[df['Year'][x],df['Month'][x],df['Temperature '][x],df['Rain'][x],df['Year'][y],df['Month'][y],df['Temperature '][y],df['Rain'][y]]
        count+=1

# %%
result1 = nd["Rain0"]
test1 = nd.drop(["Rain0","Rain1"],axis=1)
X_train1, X_test1, y_train1, y_test1 = train_test_split(test1, result1, test_size=0.9, random_state=1)
X_train1,y_train1
# Out:
# (    Year0 Month0 Temperature0 Year1 Month1 Temperature1
#  121  1914      1         18.0  1901      2         19.9
#  115  1913     12        18.15  1902      4        26.56
#  373  1902      7        27.62  1902      2        20.13
#  216  1901     11        22.17  1902      5        27.32
#  264  1902      2        20.13  1901      5        27.89
#  209  1901     11        22.17  1901     10        27.09
#  316  1902      4        26.56  1902      5        27.32
#  1    1919      5        28.17  1919      6         28.0
#  313  1902      4        26.56  1902      2        20.13
#  22   1919      7        27.79  1919      7        27.79
#  317  1902      4        26.56  1902      6        28.27
#  319  1902      4        26.56  1902      8         28.1
#  7    1919      5        28.17  1919     12        18.92
#  141  1914      2        20.68  1901      2         19.9
#  86   1920      1        18.73  1919     11        23.12
# ...

# %%
accuracy = clf.score(X_test1, y_test1)
print(accuracy)
# Out:
# 0.7535388447992006
